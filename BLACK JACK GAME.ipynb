# %%
import random
suits=('hearts','diamonds','spades','clubs')
ranks=('two','three','four','five','six','seven','eight','nine','ten','jack','queen','king','ace')
values={'two':2,'three':3,'four':4,'five':5,'six':6,'seven':7,'eight':8,'nine':9,'ten':10,'jack':10,'queen':10,'king':10,'ace':11}
playing=True

# %%
class Card():
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
        
    def __str__(self):
        return self.rank +' of '+self.suit

# %%
class Deck():
    def __init__(self):
        self.deck=[]
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))
    def __str__(self):
        deck_comp=''
        for card in self.deck:
            deck_comp +='\n' + card.__str__()
        return 'the deck has '+ deck_comp
        
    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        single_card=self.deck.pop()
        return single_card

# %%
class Hand:
    def __init__(self):
        self.cards=[]
        self.value=0
        self.aces=0
    def add_card(self,card):
        self.cards.append(card)
        self.value+=values[card.rank]
        #TRACK ACES
        if card.rank =='ace':
            self.aces +=1
    def adjust_for_ace(self):
        while self.value >21 and self.aces:
            self.value -=10
            self.aces -=1

# %%
class Chips:
    def __init__(self,total=100):
        self.total=total
        self.bet=0
    def win_bet(self):
        self.total +=self.bet
    def lose_bet(self):
        self.total -= self.bet

# %%
def take_bet(chips):
    while True:
        try:
            chips.bet=int(input('how many chips would u like to bet'))
            
        except:
            print('sorry please provide an integer')
        else:
            if chips.bet > chips.total:
                print('sorry, you dont have enough chips ! you have :{}'.format(chips.total))
            else:
                break

# %%
def hit(deck,hand):
    single_card=deck.deal()
    hand.add_card(single_card)
    hand.adjust_for_ace()

# %%
def hit_stand(deck,hand):
    global playing
    while True:
        x=input('hit or stand ?  h or s  :')
        if x[0].lower()=='h':
            hit(deck,hand)
        elif x[0].lower()=='s':
            print('player stands dealers turn ')
            playing=False
        else:
            print('sorry please try again')
            continue
        break

# %%
def show_some(player,dealer):
    print('\n dealer hand:')
    print('first card hidden')
    print(dealer.cards[1])
    print('\n players hand')
    for card in player.cards:
        print(card)
        
def show_all(player,dealer):
    print('\n dealers hand')
    for card in dealer.cards:
        print(card)
    print(f'value of dealers hand is :{dealer.value}')    
    print('\n players hand')
    for card in player.cards:
        print(card)
    print(f'value of players hand is :{player.value}')

# %%
def player_busts(player,dealer,chips):
    print('BUST PLAYER!')
    print('DEALER WINS')
    chips.lose_bet()
    
def player_wins(player,chips):
    print('player wins')
    chips.win_bet()
    
def dealer_busts(player,dealer,chips):
    print('BUST dealer!')
    print('PLAYER WINS')
    chips.lose_bet()
    
def dealer_wins(dealer,chips):
    print('dealer wins')
    chips.win_bet()
    
    
def push(player,dealer):
    print('dealer and player tie !')

# %%
while True:
    print('WELCOME TO BLACK JACK')
    deck=Deck()
    deck.shuffle()
    
    player_hand=Hand()
    player_hand.add_card(deck.deal())
    player_hand.add_card(deck.deal())
    
    dealer_hand=Hand()
    dealer_hand.add_card(deck.deal())
    dealer_hand.add_card(deck.deal())
    
    player_chips =Chips()
    take_bet(player_chips)
    show_some(player_hand,dealer_hand)
    
    while playing:
        hit_stand(deck,player_hand)
        show_some(player_hand,dealer_hand)
        if player_hand.value>21:
            player_busts(player_hand,dealer_hand,player_chips)
            break
    if player_hand.value <=21:
        while dealer_hand.value<player_hand.value:
            hit(deck,dealer_hand)
        show_all(player_hand,dealer_hand)
        if dealer_hand.value>21:
            dealer_busts(player_hand,dealer_hand,player_chips)
            
        elif dealer_hand.value >player_hand.value:
            dealer_wins(player_hand,player_chips)
        elif dealer_hand.value <player_hand.value:
            player_wins(player_hand,player_chips)
        else:
            push(player_hand,dealer_hand)
    
    print('\n player total chips are at {}'.format(player_chips.total))
    new_game=input('would you like to play another hand ? eneter  y or n :')
    if new_game[0].lower()=='y':
        playing=True
    else:
        print('thank you for playing !')
        break
# Out:
# WELCOME TO BLACK JACK
# how many chips would u like to bet50
#
#  dealer hand:
# first card hidden
# seven of hearts
#
#  players hand
# two of clubs
# three of hearts
# hit or stand ?  h or s  :h
#
#  dealer hand:
# first card hidden
# seven of hearts
#
#  players hand
# two of clubs
# three of hearts
# five of hearts
# hit or stand ?  h or s  :h
#
#  dealer hand:
# first card hidden
# seven of hearts
#
#  players hand
# two of clubs
# three of hearts
# five of hearts
# ace of clubs
# hit or stand ?  h or s  :s
# player stands dealers turn
#
#  dealer hand:
# first card hidden
# seven of hearts
#
#  players hand
# two of clubs
# three of hearts
# five of hearts
# ace of clubs
#
#  dealers hand
# king of hearts
# seven of hearts
# four of spades
# value of dealers hand is :21
#
#  players hand
# two of clubs
# three of hearts
# five of hearts
# ace of clubs
# value of players hand is :21
# dealer and player tie !
#
#  player total chips are at 100
# would you like to play another hand ? eneter  y or n :y
# WELCOME TO BLACK JACK
# how many chips would u like to bet75
#
#  dealer hand:
# first card hidden
# four of diamonds
#
#  players hand
# nine of spades
# queen of diamonds
# hit or stand ?  h or s  :s
# player stands dealers turn
#
#  dealer hand:
# first card hidden
# four of diamonds
#
#  players hand
# nine of spades
# queen of diamonds
#
#  dealers hand
# ace of spades
# four of diamonds
# nine of diamonds
# five of spades
# value of dealers hand is :19
#
#  players hand
# nine of spades
# queen of diamonds
# value of players hand is :19
# dealer and player tie !
#
#  player total chips are at 100
# would you like to play another hand ? eneter  y or n :y
# WELCOME TO BLACK JACK
# how many chips would u like to bet80
#
#  dealer hand:
# first card hidden
# nine of diamonds
#
#  players hand
# two of spades
# ten of spades
# hit or stand ?  h or s  :h
#
#  dealer hand:
# first card hidden
# nine of diamonds
#
#  players hand
# two of spades
# ten of spades
# five of diamonds
# hit or stand ?  h or s  :s
# player stands dealers turn
#
#  dealer hand:
# first card hidden
# nine of diamonds
#
#  players hand
# two of spades
# ten of spades
# five of diamonds
#
#  dealers hand
# seven of diamonds
# nine of diamonds
# six of clubs
# value of dealers hand is :22
#
#  players hand
# two of spades
# ten of spades
# five of diamonds
# value of players hand is :17
# BUST dealer!
# PLAYER WINS
#
#  player total chips are at 20
# would you like to play another hand ? eneter  y or n :no
# thank you for playing !
